# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\dhanu\Zomato_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_30004\3908794352.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   df = pd.read_csv('C:\\Users\\dhanu\Zomato_data.csv')

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
#convert rate from object to float & removing '/'

# %%
df['rate'] = df['rate'].apply(lambda x: float(str(x).split('/')[0]))
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.isnull().sum()
#no null values in dataframe
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
ax = sns.countplot(x='listed_in(type)',data = df,palette ='bright',linewidth=1.5,edgecolor='black')
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel('Type of Restuarant',size=15)
plt.title('Count of Different Restuarants',size=18,weight='bold')
plt.show()
# Out:
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_30004\2792171871.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='listed_in(type)',data = df,palette ='bright',linewidth=1.5,edgecolor='black')

# %% [markdown]
# Majority of Restuarants fall into dining category

# %%
gp = df.groupby('listed_in(type)',as_index = False).agg({"votes":'sum'})

plt.plot(gp['listed_in(type)'],gp['votes'], c ="green",marker='o')
plt.xlabel("Type of Restuarant",size=15)
plt.ylabel("Votes",size=15)
plt.title('Type of Restaurant and Votes',size=18,weight='bold')
plt.show()

# %% [markdown]
# Dining restuarants are more preferred by restuarants as it have more votes

# %%
df[df['votes']==df['votes'].max()]['name']
print('Restuarant with maxmimum votes:')
print(rest_with_maxvotes)
# Out:
# Restuarant with maxmimum votes:
# 38    Empire Restaurant
# Name: name, dtype: object

# %% [markdown]
# Empire Restuarant have highest votes

# %%
ax=sns.countplot(x='online_order',data = df,palette='rocket',linewidth=1.5,edgecolor = 'black')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Count of Orders',size=18,weight='bold')
plt.show()
# Out:
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_30004\146688568.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='online_order',data = df,palette='rocket',linewidth=1.5,edgecolor = 'black')

# %% [markdown]
# Majority of Restaurants dont accept online orders

# %%
plt.hist(x='rate',data = df , bins= 10,histtype='step',color='green')
plt.title('Rating Distribution',size=18,weight='bold')
plt.show()

# %% [markdown]
# Majority of restaurants recieved ratings from 3.5 to 4

# %%
plt.figure(figsize=(12,6))
cost_two = df['approx_cost(for two people)']
ax = sns.countplot(x=cost_two,palette ='tab10',linewidth = 1.5,edgecolor='black' )
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel('Aprroximate Cost for Two People',size=15)
plt.title('Approximate Cost for Two People',size=18,weight='bold')
# Out:
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_30004\1472290322.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=cost_two,palette ='tab10',linewidth = 1.5,edgecolor='black' )
# Text(0.5, 1.0, 'Approximate Cost for Two People')

# %% [markdown]
# Majority of couples prefer restaurants with an approx cost of 300 rupees

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x='online_order',y='rate',data = df,palette='rocket')
plt.title('Orders - Rating',size=18,weight='bold')
# Out:
# C:\Users\dhanu\AppData\Local\Temp\ipykernel_30004\418240394.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='online_order',y='rate',data = df,palette='rocket')
# Text(0.5, 1.0, 'Orders - Rating')

# %% [markdown]
# Offline orders recieved lower ratings in comparison to online orders

# %%
grouped = df.groupby(['listed_in(type)', 'online_order']).size().unstack(fill_value=0)
sns.heatmap(grouped,annot=True,cmap='YlGnBu',fmt='d')
plt.title("Heatmap",size=18,weight='bold')
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# Dining Restuarants primarly accept offline orders , where as cafes accept online orders.
# This states that customers prefer to place orders in person at dining restuarants , but prefer online ordering at cafes

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
gp = df.groupby(['listed_in(type)','book_table']).size().unstack()
colors = sns.color_palette("pastel")
gp.plot(kind='bar',stacked=True,color = colors)
plt.xlabel('Type of Restaurant')
plt.ylabel('Count')
plt.title('Table Booking Availability by Restaurant Type',size=15,weight='bold')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# Majority of dining restaurants do not offer table booking, while cafés and buffets have a smaller number of restaurants, with a few offering table booking.

# %%
#Distribution b/w Rating & Cost
sns.jointplot(x='rate', y='approx_cost(for two people)', data=df, kind='reg')

# %% [markdown]
# There is a positive correlation between restaurant ratings and cost, with most restaurants clustering around a rating of 3.5 and a cost of 300-500. The histograms show that both ratings and costs are moderately distributed, with a few outliers.
